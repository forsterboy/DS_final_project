# %%
import numpy as np
import pandas as pd
import re

# %%
energy_df = pd.read_csv('data/World Energy Consumption.csv')
energy_df.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN  \
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption
# 0                      NaN                      NaN                  NaN  \
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy
# ...

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Columns: 129 entries, country to wind_share_energy
# dtypes: float64(126), int64(1), object(2)
# memory usage: 21.7+ MB

# %%
energy_df.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct
# count  22012.000000  1.812300e+04  1.111300e+04              1747.000000  \
# mean    1974.213247  1.053096e+08  3.585114e+11                46.091694
# std       35.058653  4.640460e+08  2.411179e+12               274.616745
# min     1900.000000  1.833000e+03  1.642060e+08              -100.000000
# 25%     1946.000000  1.712404e+06  1.365898e+10                -0.616500
# 50%     1984.000000  6.991543e+06  4.167411e+10                 8.179000
# 75%     2003.000000  2.557688e+07  1.744295e+11                26.508500
# max     2022.000000  7.975105e+09  1.136302e+14              5659.328000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption
# count              2687.000000              2302.000000          2767.000000  \
# mean                  2.719074               133.558459            38.068209
# std                  10.057018               264.707851           111.623148
# ...

# %%
country_list = energy_df.country.unique()
country_list
# Out:
# array(['ASEAN (Ember)', 'Afghanistan', 'Africa', 'Africa (EI)',
#        'Africa (Ember)', 'Africa (Shift)', 'Albania', 'Algeria',
#        'American Samoa', 'Angola', 'Antarctica', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Asia & Oceania (EIA)',
#        'Asia (Ember)', 'Asia Pacific (EI)', 'Asia and Oceania (Shift)',
#        'Australia', 'Australia and New Zealand (EIA)', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'CIS (EI)', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central & South America (EIA)',
#        'Central African Republic', 'Central America (EI)',
#        'Central and South America (Shift)', 'Chad', 'Chile', 'China',
# ...

# %%
energy_df.isnull().value_counts()
# Out:
# country  year   iso_code  population  gdp    biofuel_cons_change_pct  biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  biofuel_electricity  biofuel_share_elec  biofuel_share_energy  carbon_intensity_elec  coal_cons_change_pct  coal_cons_change_twh  coal_cons_per_capita  coal_consumption  coal_elec_per_capita  coal_electricity  coal_prod_change_pct  coal_prod_change_twh  coal_prod_per_capita  coal_production  coal_share_elec  coal_share_energy  electricity_demand  electricity_generation  electricity_share_energy  energy_cons_change_pct  energy_cons_change_twh  energy_per_capita  energy_per_gdp  fossil_cons_change_pct  fossil_cons_change_twh  fossil_elec_per_capita  fossil_electricity  fossil_energy_per_capita  fossil_fuel_consumption  fossil_share_elec  fossil_share_energy  gas_cons_change_pct  gas_cons_change_twh  gas_consumption  gas_elec_per_capita  gas_electricity  gas_energy_per_capita  gas_prod_change_pct  gas_prod_change_twh  gas_p
# ...

# %%
country_array = energy_df.country.unique().tolist()
pattern = r'\b\w*countries\w*\b'
income_country_filter_list = []
for country in country_array:
    if len(re.findall(pattern, country)) != 0:
        income_country_filter_list.append(country)

# %%
pattern = r'\(\w*\)'
country_filter_list = []
for country in country_array:
    if len(re.findall(pattern, country)) != 0:
        country_filter_list.append(country)

# %%
continent_filter_list = ['Europe']
continents_df = energy_df.query('country in @continent_filter_list')
# Out:
# country  year   iso_code  population  gdp   biofuel_cons_change_pct  biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  biofuel_electricity  biofuel_share_elec  biofuel_share_energy  carbon_intensity_elec  coal_cons_change_pct  coal_cons_change_twh  coal_cons_per_capita  coal_consumption  coal_elec_per_capita  coal_electricity  coal_prod_change_pct  coal_prod_change_twh  coal_prod_per_capita  coal_production  coal_share_elec  coal_share_energy  electricity_demand  electricity_generation  electricity_share_energy  energy_cons_change_pct  energy_cons_change_twh  energy_per_capita  energy_per_gdp  fossil_cons_change_pct  fossil_cons_change_twh  fossil_elec_per_capita  fossil_electricity  fossil_energy_per_capita  fossil_fuel_consumption  fossil_share_elec  fossil_share_energy  gas_cons_change_pct  gas_cons_change_twh  gas_consumption  gas_elec_per_capita  gas_electricity  gas_energy_per_capita  gas_prod_change_pct  gas_prod_change_twh  gas_pr
# ...

# %%
continent_filter_list = ['ASEAN ', 'Africa', 'Asia', 'Asia & Oceania', 'Asia Pacific', 'Europe', 'North America', 'South America']
# Out:
#              country  year iso_code   population  gdp
# 145           Africa  1900      NaN  138752199.0  NaN  \
# 146           Africa  1901      NaN  139021447.0  NaN
# 147           Africa  1902      NaN  139489077.0  NaN
# 148           Africa  1903      NaN  139992790.0  NaN
# 149           Africa  1904      NaN  140510536.0  NaN
# ...              ...   ...      ...          ...  ...
# 18052  South America  2018      NaN  424740741.0  NaN
# 18053  South America  2019      NaN  428318218.0  NaN
# 18054  South America  2020      NaN  431530105.0  NaN
# 18055  South America  2021      NaN  434254167.0  NaN
# 18056  South America  2022      NaN  436816679.0  NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh
# 145                        NaN                      NaN  \
# 146                        NaN                      NaN
# 147                        NaN                      NaN
# 148                        NaN                      NaN
# ...

# %%
# Energy informations distributed to diff. income countries
energy_income_countries_df = energy_df.query('country in @income_country_filter_list')
# Grouped information from diff. organisations vs                                    
energy_grouped_countries_df = energy_df.query('country in @country_filter_list')
# Continental energy consumption information
energy_continental_df = energy_df.query('country in @continent_filter_list')

#
energy_countries_df = energy_df.query('country not in @income_country_filter_list and country not in @country_filter_list and country not in @continent_filter_list')

# %%
print(energy_income_countries_df.shape)
print(energy_grouped_countries_df.shape)
print(energy_continental_df.shape)
print(energy_countries_df.shape)
print('Rows ', energy_income_countries_df.shape[0] + energy_grouped_countries_df.shape[0] + energy_continental_df.shape[0] + energy_countries_df.shape[0])
# Out:
# (492, 129)
# (3846, 129)
# (615, 129)
# (17059, 129)
# Rows  22012

# %%
energy_df.shape[0] / len(energy_df.country.unique())
# Out:
# 71.93464052287581

# %%
energy_income_countries_df.groupby('country').mean
# Out:
#                              country  year iso_code    population  gdp
# 8636           High-income countries  1900      NaN  4.419288e+08  NaN  \
# 8637           High-income countries  1901      NaN  4.454262e+08  NaN
# 8638           High-income countries  1902      NaN  4.502080e+08  NaN
# 8639           High-income countries  1903      NaN  4.551713e+08  NaN
# 8640           High-income countries  1904      NaN  4.602040e+08  NaN
# ...                              ...   ...      ...           ...  ...
# 20945  Upper-middle-income countries  2018      NaN  2.516786e+09  NaN
# 20946  Upper-middle-income countries  2019      NaN  2.530546e+09  NaN
# 20947  Upper-middle-income countries  2020      NaN  2.541464e+09  NaN
# 20948  Upper-middle-income countries  2021      NaN  2.548718e+09  NaN
# 20949  Upper-middle-income countries  2022      NaN  2.555056e+09  NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh
# 8636                       NaN                      NaN  \
# ...
